# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import pandas as pd
import os
import glob

# os.chdir("./dataset/")

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-3-7ce2d5030b45> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount("/content/gdrive")
#       3
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     113       force_remount=force_remount,
#     114       timeout_ms=timeout_ms,
# --> 115       ephemeral=True)
#     116
#     117
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, use_metadata_server, ephemeral)
#     133   if ephemeral:
#     134     _message.blocking_request(
# --> 135         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     136
#     137   mountpoint = _os.path.expanduser(mountpoint)
#
# ...

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/1Tbmin-u1y2IgHVAYxtd8XXmTSKzTeZcUiXSIAAhMykY/edit?usp=sharing', sep=',')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-4-8f8f9ca6a81a> in <module>()
# ----> 1 df = pd.read_csv('https://docs.google.com/spreadsheets/d/1Tbmin-u1y2IgHVAYxtd8XXmTSKzTeZcUiXSIAAhMykY/edit?usp=sharing', sep=',')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df
# Out:
#                                                 track                 artist  \
# 0                                         Misty Roses        Astrud Gilberto
# 1                                          Never Ever             All Saints
# 2                                         Soul Sermon          Gregg Karukas
# 3                           Clarinet Marmalade - Live          Alton Purnell
# 4      До смерті і довше - Drum & Base and Rock Remix               Skryabin
# ...                                               ...                    ...
# 41101                             Born with the Blues          Buster Benton
# 41102                        Farther On Down The Road              Joe Simon
# 41103                                      Sweetheart  Engelbert Humperdinck
# 41104                   Until It's Time For You To Go           Neil Diamond
# 41105                   Try Me, I Know We Can Make It           Donna Summer
#
# ...

# %%
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#combine all files in the list
data = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
data.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')

# %%
data
# Out:
#                                                track                 artist  \
# 0                                        Misty Roses        Astrud Gilberto
# 1                                         Never Ever             All Saints
# 2                                        Soul Sermon          Gregg Karukas
# 3                          Clarinet Marmalade - Live          Alton Purnell
# 4     До смерті і довше - Drum & Base and Rock Remix               Skryabin
# ...                                              ...                    ...
# 7761                             Born with the Blues          Buster Benton
# 7762                        Farther On Down The Road              Joe Simon
# 7763                                      Sweetheart  Engelbert Humperdinck
# 7764                   Until It's Time For You To Go           Neil Diamond
# 7765                   Try Me, I Know We Can Make It           Donna Summer
#
# ...

# %%
df.columns
# Out:
# Index(['track', 'artist', 'uri', 'danceability', 'energy', 'key', 'loudness',
#        'mode', 'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature', 'chorus_hit',
#        'sections', 'target'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.values
# Out:
# array([['Misty Roses', 'Astrud Gilberto',
#         'spotify:track:50RBM1j1Dw7WYmsGsWg9Tm', ..., 53.89523, 6, 0],
#        ['Never Ever', 'All Saints',
#         'spotify:track:5FTz9qQ94PyUHETyAyfYZN', ..., 32.16853, 16, 1],
#        ['Soul Sermon', 'Gregg Karukas',
#         'spotify:track:6m24oe3lk1UMxq9zq4iPFi', ..., 42.05369, 9, 0],
#        ...,
#        ['Sweetheart', 'Engelbert Humperdinck',
#         'spotify:track:6zm0XoxnzzdFeXeYGE8gFh', ..., 22.28247, 12, 1],
#        ["Until It's Time For You To Go", 'Neil Diamond',
#         'spotify:track:6fsAxEHvbVPU8pVPnBXaX2', ..., 19.82409, 10, 1],
#        ['Try Me, I Know We Can Make It', 'Donna Summer',
#         'spotify:track:75y3G2V8wSpm89einsZ4d5', ..., 41.00309, 10, 1]],
#       dtype=object)

# %%
df.shape
# Out:
# (41106, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41106 entries, 0 to 41105
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track             41106 non-null  object
#  1   artist            41106 non-null  object
#  2   uri               41106 non-null  object
#  3   danceability      41106 non-null  float64
#  4   energy            41106 non-null  float64
#  5   key               41106 non-null  int64
#  6   loudness          41106 non-null  float64
#  7   mode              41106 non-null  int64
#  8   speechiness       41106 non-null  float64
#  9   acousticness      41106 non-null  float64
#  10  instrumentalness  41106 non-null  float64
#  11  liveness          41106 non-null  float64
#  12  valence           41106 non-null  float64
#  13  tempo             41106 non-null  float64
#  14  duration_ms       41106 non-null  int64
#  15  time_signature    41106 non-null  int64
# ...

# %%
df['artist']
# Out:
# 0              Astrud Gilberto
# 1                   All Saints
# 2                Gregg Karukas
# 3                Alton Purnell
# 4                     Skryabin
#                  ...
# 41101            Buster Benton
# 41102                Joe Simon
# 41103    Engelbert Humperdinck
# 41104             Neil Diamond
# 41105             Donna Summer
# Name: artist, Length: 41106, dtype: object

# %%
type(df['artist'])
# Out:
# pandas.core.series.Series

# %%
# looking for a specific row given the index: (iloc = index location)
df.iloc[2]
# Out:
# track                                        Soul Sermon
# artist                                     Gregg Karukas
# uri                 spotify:track:6m24oe3lk1UMxq9zq4iPFi
# danceability                                       0.736
# energy                                             0.419
# key                                                    0
# loudness                                         -10.662
# mode                                                   1
# speechiness                                         0.03
# acousticness                                       0.693
# instrumentalness                                   0.495
# liveness                                          0.0809
# valence                                            0.265
# tempo                                             93.982
# duration_ms                                       237267
# time_signature                                         4
# ...
